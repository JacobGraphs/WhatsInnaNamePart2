# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../data/new_data/cleaned_movies.csv')

# %%
df['genre'].unique()
# Out:
# array(['Drama, Romance, War', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Family', 'Animation, Family, Fantasy',
#        'Drama, History, Romance', 'Comedy, Drama',
#        'Adventure, Family, Fantasy', 'Animation, Comedy, Family',
#        'Drama, Mystery', 'Biography, Drama, History',
#        'Crime, Drama, Film-Noir', 'Drama, Romance, Western',
#        'Comedy, Crime, Drama', 'Drama, Film-Noir', 'Drama',
#        'Drama, Family, Romance', 'Comedy, Musical, Romance',
#        'Film-Noir, Thriller', 'Animation, Adventure, Family', 'Horror',
#        'Drama, Family', 'Drama, History', 'Drama, War', 'Crime, Thriller',
#        'Mystery, Thriller', 'Drama, Musical, Romance',
#        'Animation, Adventure, Comedy', 'Adventure, Drama',
#        'Drama, Western', 'Adventure, Comedy, Family',
#        'Musical, Romance, War', 'Mystery, Romance, Thriller',
#        'Adventure, Drama, History', 'Horror, Mystery, Thriller',
#        'Adventure, Biography, Drama', 'Adventure, Family',
#        'Crime, Drama, Musical', 'Western', 'Drama, Thriller',
#        'Crime, Drama', 'Action, Adventure, Comedy', 'Drama, Romance',
#        'Drama, Family, Musical', 'Comedy, Family, Fantasy',
#        'Adventure, War, Western', 'Biography, Drama, Family',
#        'Comedy, Music', 'Comedy', 'Action, Crime, Thriller',
#        'Action, Comedy, Crime', 'Biography, Comedy, Drama',
#        'Adventure, Sci-Fi', 'Action, Adventure, Western',
#        'Comedy, Drama, Musical', 'Adventure, Comedy, Musical',
#        'Biography, Crime, Drama', 'Comedy, Crime, Horror',
#        'Comedy, Drama, Fantasy', 'Comedy, Drama, War',
#        'Adventure, Comedy, Drama', 'Biography, Drama, War',
#        'Action, Adventure, Sci-Fi', 'Action, Drama, Thriller',
#        'Adventure, Comedy, War', 'Action, Crime, Drama', 'Action, Sci-Fi',
#        'Drama, Sci-Fi, Thriller', 'Action, Adventure, Drama',
#        'Comedy, Sci-Fi', 'Crime, Drama, Thriller',
#        'Drama, Mystery, Western', 'Drama, Mystery, Thriller',
#        'Comedy, Western', 'Adventure, Family, Romance',
#        'Comedy, Drama, Music', 'Comedy, War',
#        'Adventure, Drama, Thriller', 'Horror, Sci-Fi', 'Comedy, Musical',
#        'Drama, Sport', 'Drama, Music, Romance', 'Adventure, Horror',
#        'Action, Adventure, Fantasy', 'Action, Comedy', 'Drama, Music',
#        'Drama, Music, Musical', 'Drama, Sci-Fi', 'Drama, History, War',
#        'Comedy, Romance', 'Comedy, Mystery, Thriller', 'Horror, Thriller',
#        'Comedy, Music, Romance', 'Adventure, Drama, Horror',
#        'Adventure, Comedy, Fantasy', 'Musical, Romance', 'Action, Drama',
#        'Biography, Drama, Music', 'Comedy, Drama, Mystery',
#        'Adventure, Comedy', 'Adventure, Mystery, Sci-Fi',
#        'Horror, Sci-Fi, Thriller', 'Comedy, Drama, Western',
#        'Action, Comedy, War', 'Drama, Mystery, War',
#        'Comedy, Family, Western', 'Adventure, Family, Sport',
#        'Adventure, Romance, Thriller', 'Comedy, Horror, Thriller',
#        'Comedy, Crime, Mystery', 'Action, Drama, Romance',
#        'Comedy, Crime, Fantasy', 'Action, Comedy, Drama',
#        'Biography, Drama, Sport', 'Adventure, Comedy, Crime',
#        'Drama, Fantasy, Romance', 'Fantasy, Musical, Romance',
#        'Action, Biography, Comedy', 'Biography, Crime, Western',
#        'Adventure, Drama, Western', 'Crime, Drama, Mystery',
#        'Adventure, Drama, Romance', 'Comedy, Sport',
#        'Adventure, Thriller', 'Action, Adventure',
#        'Adventure, Crime, Thriller', 'Biography, Music',
#        'Biography, Drama', 'Comedy, History', 'Drama, Romance, Thriller',
#        'Comedy, Fantasy, Sci-Fi', 'Animation, Adventure, Drama',
#        'Drama, Horror, Thriller', 'Action, Crime, Horror',
#        'Action, Adventure, Thriller', 'Comedy, Drama, Thriller',
#        'Drama, Horror', 'Comedy, Crime', 'Horror, Mystery, Sci-Fi',
#        'Crime, Drama, Western', 'Fantasy, Horror, Thriller',
#        'Comedy, Fantasy, Horror', 'Sci-Fi, Comedy, Music',
#        'Family, Sci-Fi', 'Fantasy, Mystery, Thriller',
#        'Crime, Drama, Romance', 'Sci-Fi, Thriller',
#        'Drama, Romance, Sport', 'Animation, Fantasy, Adventure',
#        'Adventure, Horror, Thriller', 'Comedy, Fantasy, Romance',
#        'Comedy, Horror, Sci-Fi', 'Romance, Sci-Fi',
#        'Drama, Thriller, Crime', 'Comedy, Crime, Sci-Fi',
#        'Action, Adventure, Crime', 'Action, Drama, Family',
#        'Action, Horror, Sci-Fi', 'Crime, Drama, Music',
#        'Action, Comedy, Fantasy', 'Comedy, Romance, Sci-Fi',
#        'Adventure, Fantasy, Mystery', 'Comedy, Thriller',
#        'Adventure, Comedy, Sci-Fi', 'Comedy, Drama, Sci-Fi',
#        'Adventure, Fantasy, Romance', 'Action, Thriller',
#        'Crime, Horror, Mystery', 'Comedy, Horror, Musical',
#        'Comedy, Crime, Romance', 'Action, Comedy, Horror',
#        'Comedy, Horror', 'Adventure, Family, Sci-Fi',
#        'Comedy, Family, Sci-Fi', 'Adventure', 'Adventure, Drama, Fantasy',
#        'Comedy, Drama, Sport', 'Comedy, Romance, Sport',
#        'Action, Sci-Fi, Thriller', 'Action, Crime, Sci-Fi',
#        'Action, Drama, Sport', 'Fantasy, Horror', 'Thriller',
#        'Comedy, Mystery, Romance', 'Crime, Drama, Horror', 'Action',
#        'Comedy, Crime, Thriller', 'Comedy, Fantasy',
#        'Drama, Mystery, Romance', 'Comedy, Family',
#        'Action, Drama, Horror', 'Comedy, Mystery', 'Fantasy, Comedy',
#        'Action, Comedy, Sci-Fi', 'Action, Fantasy, Horror',
#        'Crime, Drama, History', 'Drama, Horror, Sci-Fi',
#        'Adventure, Comedy, Romance', 'Action, Western',
#        'Adventure, Comedy, Mystery', 'Action, Biography, Drama',
#        'Fantasy, Horror, Mystery', 'Action, Crime, Mystery',
#        'Drama, History, Sport', 'Crime, Mystery, Romance',
#        'Action, Sport', 'Comedy, Action', 'Crime, Horror, Thriller',
#        'Crime, Drama, War', 'Adventure, Comedy, Music',
#        'Action, Sport, Thriller', 'Adventure, Drama, Mystery',
#        'Fantasy, Romance', 'Action, Drama, Mystery',
#        'Animation, Adventure, Crime', 'Drama, Horror, Mystery',
#        'Drama, Horror, Romance', 'Action, Adventure, Family',
#        'Comedy, Horror, Mystery', 'Action, Crime',
#        'Drama, Family, History', 'Crime, Mystery, Thriller',
#        'Action, Comedy, Family', 'Comedy, Crime, Family',
#        'Animation, Comedy, Fantasy', 'Drama, Comedy',
#        'Comedy, Romance, Thriller', 'Family, Fantasy, Music',
#        'Comedy, Family, Romance', 'Comedy, Family, Music',
#        'Animation, Action, Adventure', 'Adventure, Comedy, Sport',
#        'Biography, Drama, Fantasy', 'Drama, History, Western',
#        'Action, Drama, Sci-Fi', 'Comedy, Family, Sport',
#        'Adventure, Biography, Crime', 'Action, Comedy, Thriller',
#        'Action, Adventure, Mystery', 'Comedy, Action, Crime',
#        'Action, Adventure, Romance', 'Crime, Drama, Sport',
#        'Action, Drama, Fantasy', 'Crime, Comedy, Drama',
#        'Action, Comedy, Romance', 'Drama, Fantasy, Mystery',
#        'Comedy, Romance, Drama', 'Action, Biography, Western',
#        'Mystery, Sci-Fi, Thriller', 'Drama, Fantasy',
#        'Drama, Family, Fantasy', 'Action, Crime, Romance',
#        'Comedy, Fantasy, Musical', 'Action, Romance, Thriller',
#        'Comedy, Fantasy, Mystery', 'Biography, Drama, Romance',
#        'Drama, Mystery, Sci-Fi', 'Horror, Mystery',
#        'Action, Crime, Fantasy', 'Drama, Fantasy, Horror',
#        'Crime, Romance, Thriller', 'Animation, Drama, Family',
#        'Adventure, Drama, Family', 'Fantasy, Action, Adventure',
#        'Biography, Romance', 'Animation, Comedy, Drama', 'Sci-Fi',
#        'Crime, Thriller, Drama', 'Action, Drama, History',
#        'Romance, Comedy', 'Action, Mystery, Thriller',
#        'Action, Adventure, Horror', 'Biography, Comedy, Romance',
#        'Drama, History, Horror', 'Adventure, Comedy, Western',
#        'Thriller, Action', 'Family, Drama', 'Drama, Fantasy, Thriller',
#        'Music', 'Crime, Drama, Fantasy', 'Biography, Drama, Thriller',
#        'Action, Adventure, History', 'Crime, Drama, Action',
#        'Romance, Thriller', 'Adventure, Sci-Fi, Thriller',
#        'Comedy, Mystery, Sci-Fi', 'Adventure, Fantasy, Horror',
#        'Action, Drama, Crime', 'Drama, Fantasy, Sport',
#        'Drama, History, Thriller', 'Action, Horror, Thriller',
#        'Crime, Horror', 'Drama, Fantasy, Sci-Fi',
#        'Romance, Comedy, Drama', 'Drama, Family, Sport',
#        'Action, Drama, War', 'Action, Horror, Mystery',
#        'Animation, Comedy, Musical', 'Drama, Romance, Comedy',
#        'Adventure, Thriller, Western', 'Comedy, Crime, Musical',
#        'Family, Music, Musical', 'Romance, Drama',
#        'Drama, Romance, Sci-Fi', 'Comedy, Crime, Music',
#        'Animation, Comedy, Crime', 'Comedy, Crime, Sport',
#        'Drama, Sport, Thriller', 'Biography, Comedy',
#        'Animation, Family, Romance', 'Drama, Family, Western',
#        'Adventure, Drama, Sci-Fi', 'Animation, Crime, Drama',
#        'Animation, Family', 'Fantasy, Horror, Sci-Fi',
#        'Horror, Musical, Sci-Fi', 'Mystery', 'Drama, Thriller, War',
#        'Drama, Musical', 'Action, Fantasy', 'Biography, Comedy, Crime',
#        'Romance', 'Action, Comedy, Music', 'Animation, Drama, Fantasy',
#        'Adventure, Comedy, Horror', 'Animation, Action, Comedy',
#        'Action, Comedy, Musical', 'Romance, Sci-Fi, Thriller',
#        'Action, Biography, Crime', 'Action, Fantasy, Thriller',
#        'Comedy, Horror, Romance', 'Action, Comedy, Sport',
#        'Comedy, Fantasy, Thriller', 'Thriller, Western',
#        'Drama, History, Mystery', 'Drama, Family, Music', 'Crime',
#        'Sport', 'Drama, Fantasy, Music', 'Comedy, Drama, Horror',
#        'Comedy, Music, War', 'Horror, Music, Thriller',
#        'Drama, Family, Thriller', 'Action, Mystery, Sci-Fi',
#        'Action, Drama, Western', 'Adventure, Biography, Comedy',
#        'Adventure, Crime, Drama', 'Musical', 'Animation, Action, Crime',
#        'Biography, Family, Sport', 'Family, Fantasy, Musical',
#        'Crime, Thriller, Western', 'Biography, Drama, Musical',
#        'Family, Romance', 'Fantasy, Horror, Musical',
#        'Biography, Drama, Western', 'Action, Horror'], dtype=object)

# %%
x = list(df['genre'].unique())
genres = []
for i in x:
    y = i.split(', ')
    for g in y:
        genres.append(g)
genres_set = set(genres)
print(genres_set)
# Out:
# {'Sport', 'Romance', 'Family', 'War', 'Biography', 'Adventure', 'Western', 'Action', 'Music', 'Animation', 'Horror', 'Fantasy', 'History', 'Mystery', 'Sci-Fi', 'Drama', 'Film-Noir', 'Thriller', 'Musical', 'Comedy', 'Crime'}

# %%
def genre_determine(g, row):
    if g in row['genre']:
        return 1
    else:
        return 0

# %%
for genre in genres_set:
    col_name = 'is_' + genre
    df[col_name] = df.apply(lambda row: genre_determine(genre, row), axis = 1)

# %%
df.to_csv('../../data/new_data/final.csv')

# %%
df.sample(5)
# Out:
#       Unnamed: 0                                    title         director  \
# 747        22949                            Above the Law     Andrew Davis
# 1985       35629                           The Ladies Man  Reginald Hudlin
# 3494       57116                            A Better Life      Chris Weitz
# 4075       62153                                Mr. Right     Paco Cabezas
# 1601       29995  Midnight in the Garden of Good and Evil   Clint Eastwood
#
#                                             description  duration  year  \
# 747   A former Special Operations Vietnam vet works ...        99  1988
# 1985  The Saturday Night Live character gets a big s...        84  2000
# 3494  A gardener in East L.A. struggles to keep his ...        98  2011
# 4075  A girl falls for the "perfect" guy, who happen...        95  2015
# 1601  A visiting city reporter's (John Cusack's) ass...       155  1997
#
#         budget                    genre  profitable  is_Sport  ...  \
# 747    7500000     Action, Crime, Drama           1         0  ...
# 1985  24000000                   Comedy           0         0  ...
# 3494  10000000           Drama, Romance           0         0  ...
# 4075   8000000  Action, Comedy, Romance           0         0  ...
# 1601  35000000    Crime, Drama, Mystery           0         0  ...
#
#       is_Fantasy  is_History  is_Mystery  is_Sci-Fi  is_Drama  is_Film-Noir  \
# 747            0           0           0          0         1             0
# 1985           0           0           0          0         0             0
# 3494           0           0           0          0         1             0
# 4075           0           0           0          0         0             0
# 1601           0           0           1          0         1             0
#
#       is_Thriller  is_Musical  is_Comedy  is_Crime
# 747             0           0          0         1
# 1985            0           0          1         0
# 3494            0           0          0         0
# 4075            0           0          1         0
# 1601            0           0          0         1
#
# [5 rows x 30 columns]
